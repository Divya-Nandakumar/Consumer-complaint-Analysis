# %%
 """ 1.3 - Import LIBRARIES"""
import pandas as pd
import numpy as np
# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')
# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')
# display all columns of the dataframe
pd.options.display.max_columns = None
# display all rows of the dataframe
pd.options.display.max_rows = None
# to display the float values upto 6 decimal places     
pd.options.display.float_format = '{:.6f}'.format
# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')
# display all columns of the dataframe
pd.options.display.max_columns = None
# display all rows of the dataframe
pd.options.display.max_rows = None
# to display the float values upto 6 decimal places     
pd.options.display.float_format = '{:.6f}'.format


                             #MAIN Libraries
# import 'pandas' 
import pandas as pd 
# import 'pandas profiling' 
#import pandas_profiling as pp
# import 'numpy' 
import numpy as np
# import subpackage of matplotlib
import matplotlib.pyplot as plt
# import 'seaborn'
import seaborn as sns
# import 'random' to generate random sample
import random
# import statistics to perform statistical computation  
import statistics
# import 'stats' package from scipy library
from scipy import stats
# import a library to perform Z-test
from statsmodels.stats import weightstats as stests
# to test the normality 
from scipy.stats import shapiro
# import the function to calculate the power of test
from statsmodels.stats import power
import scipy.stats as stats
# importing sweetviz
#import sweetviz as sv
#import dtale
#import dtale
#Altair
#import altair as alt
#Datapane
#import datapane as dp
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
# import subpackage of Matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# import 'Seaborn' 
import seaborn as sns


# import various functions from statsmodels
import statsmodels
import statsmodels.api as sm

# scaling
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# train-test split 
from sklearn.model_selection import train_test_split


#  feature selection
from sklearn.feature_selection import RFE
from sklearn import tree
from sklearn.model_selection import GridSearchCV

# machine learning classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm  import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
import pydotplus
from IPython.display import Image  
from sklearn.ensemble import RandomForestClassifier


# performance metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import make_scorer
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score 

from imblearn.under_sampling import RandomUnderSampler

# %%
data=pd.read_csv("C:/Users/Lavanya/OneDrive/Great Lakes/Capstone project/capstone_reference/GL project datasets/rows.csv")
data.head()
# Out:
#   Date received                                            Product  \
# 0    05-10-2019                        Checking or savings account
# 1    05-10-2019                        Checking or savings account
# 2    05-10-2019                                    Debt collection
# 3    05-10-2019  Credit reporting, credit repair services, or o...
# 4    05-10-2019                        Checking or savings account
#
#                         Sub-product                                 Issue  \
# 0                  Checking account                   Managing an account
# 1  Other banking product or service                   Managing an account
# 2                  Payday loan debt                 Communication tactics
# 3                  Credit reporting  Incorrect information on your report
# 4                  Checking account                   Managing an account
#
#                                       Sub-issue Consumer complaint narrative  \
# 0             Problem using a debit or ATM card                          NaN
# 1                      Deposits and withdrawals                          NaN
# 2                    Frequent or repeated calls                          NaN
# 3  Old information reappears or never goes away                          NaN
# 4                                Banking errors                          NaN
#
#   Company public response                         Company State ZIP code  \
# 0                     NaN       NAVY FEDERAL CREDIT UNION    FL    328XX
# 1                     NaN   BOEING EMPLOYEES CREDIT UNION    WA    98204
# 2                     NaN      CURO Intermediate Holdings    TX    751XX
# 3                     NaN  Ad Astra Recovery Services Inc    LA    708XX
# 4                     NaN             ALLY FINANCIAL INC.    AZ    85205
#
#              Tags Consumer consent provided? Submitted via  \
# 0  Older American                        NaN           Web
# 1             NaN                        NaN      Referral
# 2             NaN                        NaN           Web
# 3             NaN                        NaN           Web
# 4             NaN                        NaN   Postal mail
#
#   Date sent to company Company response to consumer Timely response?  \
# 0           05-10-2019                  In progress              Yes
# 1           05-10-2019      Closed with explanation              Yes
# 2           05-10-2019      Closed with explanation              Yes
# 3           05-10-2019      Closed with explanation              Yes
# 4           05-10-2019                  In progress              Yes
#
#   Consumer disputed?  Complaint ID
# 0                NaN       3238275
# 1                NaN       3238228
# 2                NaN       3237964
# 3                NaN       3238479
# 4                NaN       3238460

# %%
data.isnull().sum()
# Out:
# Date received                        0
# Product                              0
# Sub-product                     174377
# Issue                                0
# Sub-issue                       348920
# Consumer complaint narrative    665011
# Company public response         599524
# Company                              0
# State                            17497
# ZIP code                        113394
# Tags                            902033
# Consumer consent provided?      357921
# Submitted via                        0
# Date sent to company                 0
# Company response to consumer         7
# Timely response?                     0
# Consumer disputed?              513854
# Complaint ID                         0
# dtype: int64

# %%
data=data.drop(['Tags','Consumer complaint narrative','Company public response','ZIP code'],axis=1)

# %%
trial  = data.dropna()

# %%
trial['Timely response?'].value_counts()
# Out:
# Yes    84106
# No      6413
# Name: Timely response?, dtype: int64

# %%
data['Timely response?'].value_counts()
# Out:
# Yes    1021352
# No       27223
# Name: Timely response?, dtype: int64

# %%
y1 = data['Timely response?']

# %%
x1 = data.drop('Timely response?',axis=1)

# %%
from collections import Counter

# %%
rus = RandomUnderSampler(random_state=42, replacement=False)# fit predictor and target variable 
# null values in target variable need to be eliminated 
x_rus1, y_rus1 = rus.fit_resample(x1, y1)

print('original dataset shape:', Counter(y1))
print('Resample dataset shape', Counter(y_rus1))
# Out:
# original dataset shape: Counter({'Yes': 1021352, 'No': 27223})
# Resample dataset shape Counter({'No': 27223, 'Yes': 27223})

# %%
final = pd.concat([x_rus1,y_rus1],axis=1)

# %%
final.head()
# Out:
#   Date received                                            Product  \
# 0    04/27/2019  Credit reporting, credit repair services, or o...
# 1    04/27/2019          Payday loan, title loan, or personal loan
# 2    04/27/2019                                    Debt collection
# 3    04/27/2019                                    Debt collection
# 4    04/27/2019                                    Debt collection
#
#         Sub-product                                              Issue  \
# 0  Credit reporting  Problem with a credit reporting company's inve...
# 1  Installment loan  Problem with additional add-on products or ser...
# 2         Auto debt  Took or threatened to take negative or legal a...
# 3        Other debt                  Attempts to collect debt not owed
# 4        Other debt  Took or threatened to take negative or legal a...
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1                                                NaN
# 2  Sued you without properly notifying you of law...
# 3                                      Debt was paid
# 4            Threatened to sue you for very old debt
#
#                                              Company State  \
# 0                           First Advantage LNS Inc.    MD
# 1                 College Lending Solutions of Salem    LA
# 2  Creditmax Collection Agency, Inc. d/b/a Credit...    IN
# 3                                 Biehl & Biehl, Inc    CA
# 4                     Genesis Credit Management, LLC    ID
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           04/28/2019
# 1                        NaN           Web           04/27/2019
# 2                        NaN           Web           04/27/2019
# 3                        NaN           Web           04/27/2019
# 4                        NaN           Web           04/27/2019
#
#   Company response to consumer Consumer disputed?  Complaint ID  \
# 0            Untimely response                NaN       3225173
# 1            Untimely response                NaN       3225144
# 2            Untimely response                NaN       3225162
# 3            Untimely response                NaN       3224666
# 4            Untimely response                NaN       3224729
#
#   Timely response?
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No

# %%
final.isnull().sum()/len(final)*100
# Out:
# Date received                   0.000000
# Product                         0.000000
# Sub-product                    10.886016
# Issue                           0.000000
# Sub-issue                      31.243801
# Company                         0.000000
# State                           1.643831
# Consumer consent provided?     32.303567
# Submitted via                   0.000000
# Date sent to company            0.000000
# Company response to consumer    0.001837
# Consumer disputed?             44.344855
# Complaint ID                    0.000000
# Timely response?                0.000000
# dtype: float64

# %%
final.to_excel('C:/Users/Lavanya/OneDrive/Great Lakes/Capstone project/Timely_res_final_dataset.xlsx')
